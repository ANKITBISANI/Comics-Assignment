# %%
# GET 15 random comics and following details in using Python.
#   a. Get the names of the comic
#   b. Get the alt-text of the comic
#   c. Get the number of the comic
#   d. Get the link of the comic
#   e. Get the image of the comics
#   f. Get the image Link of the comics

#   Insert into MySQL - Please include SQL database schema(s) for any table(s) created in your Github repo

###############################################################################################################
# Created by : Ankit Bisani
# Date:12-08-2021
# 
# 
###############################################################################################################
# host='localhost'
# user='root', 
#password = "*****",(root password of the user )
#db='comics'
###############################################################################################################

import requests
import random
import json
import pymysql
import sys
 
# total arguments

conn = pymysql.connect(
        host='localhost',
        user='root', 
        password = "March@1988",
        db='comics',
        )


def comic_details_mysql_dump():
    
    list=[]
    
    for i in random.sample(range(1, 84), 15):
        web= 'https://xkcd.com/'
        number=str(i)
        extension='/info.0.json'
    
  #URL Generation
        URL=web+number+extension
        
        
    
  # sending get request 

        try:
            r = requests.get(url = URL)
            r.raise_for_status()
            
            
    
   # extracting data in json format and cleaning/transforming the the data 

        
        
            title = r.json()['title']
            alt_text = r.json()['alt']
            num = r.json()['num']
            link = r.json()['link']
            image_link = r.json()['img']
            image=r.json()['img'].rsplit('/', 1)[1]
            
            print(title,alt_text,num,link,image_link,image)
            
            
        
            # To connect MySQL database
            
              
            cur = conn.cursor()
            
            
            SQL = 'INSERT INTO comics_details (names, alt_text, number,link,image,image_link) VALUES ("{}", "{}", "{}", "{}", "{}", "{}")'.format(title,alt_text,num,link,image_link,image)
            cur.execute(SQL)
            
            output = cur.fetchall()
            
              
            
            conn.commit()
            
        except requests.exceptions.HTTPError as errh:
            print(errh)
        except requests.exceptions.ConnectionError as errc:
            print(errc)


        
def main():
    comic_details_mysql_dump()
    
if __name__=='__main__':
    main()
# Out:
# Pillow Talk Maybe I should've tried Wexler? 69  https://imgs.xkcd.com/comics/pillow_talk.jpg pillow_talk.jpg
# Barrel - Part 4 :( 25  https://imgs.xkcd.com/comics/barrel_part_4.jpg barrel_part_4.jpg
# Hobby The only one of these games I really played was Area 51 53  https://imgs.xkcd.com/comics/hobby.jpg hobby.jpg
# Island (sketch) Hello, island 3  https://imgs.xkcd.com/comics/island_color.jpg island_color.jpg
# Love This one makes me wince every time I think about it 44  https://imgs.xkcd.com/comics/love.jpg love.jpg
# Red Spiders 2 This was actually drawn years before Red Spiders 43  https://imgs.xkcd.com/comics/red_spiders_2.jpg red_spiders_2.jpg
# Meat Cereals Disgusting 27  https://imgs.xkcd.com/comics/meat_cereals.jpg meat_cereals.jpg
# Pillar A comic by my brother Doug, redrawn and rewritten by me 32  https://imgs.xkcd.com/comics/pillar.jpg pillar.jpg
# Garfield The use of the 'Garfield' character for the purposes of this parody qualifies as fair use under the Copyright Act of 1976, 17 U.S.C. sec. 107.  See Campbell v. Acuff-Rose Music (92-1292), 510 U.S. 569 78  https://imgs.xkcd.com/comics/garfield.jpg garfield.jpg
# Self-reference I think about self-reference a lot.  Example: this comment. 33  https://imgs.xkcd.com/comics/self-reference.jpg self-reference.jpg
# Barrel - Part 2 Awww. 11  https://imgs.xkcd.com/comics/barrel_mommies.jpg barrel_mommies.jpg
# Solar Plexus It hurts to be hit there, you know 64  https://imgs.xkcd.com/comics/solar_plexus.jpg solar_plexus.jpg
# Poisson Poisson distributions have no value over negative numbers 12  https://imgs.xkcd.com/comics/poisson.jpg poisson.jpg
# Blown apart Blown into prime factors 5  https://imgs.xkcd.com/comics/blownapart_color.jpg blownapart_color.jpg
# Super Bowl The Super Bowl is actually an elaborate ruse, concocted by a shadowy group in the mid sixties for this purpose.  The 'watch it for the ads' addition was a master stroke. 60  https://imgs.xkcd.com/comics/super_bowl.jpg super_bowl.jpg
