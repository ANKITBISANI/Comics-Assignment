# %%
# Write a script called task_one.py that when called will output something like this to theconsole. (reference below).



###############################################################################################################
# Created by : Ankit Bisani
# Date:12-08-2021
# 
# 
###############################################################################################################


import requests
import random
import json



import sys
 
# total arguments


  
# api-endpoint

 
def comic_details():
    
    list=[]
    
    for i in random.sample(range(1, 84), 15):
        web= 'https://xkcd.com/'
        number=str(i)
        extension='/info.0.json'
    
  #URL Generation
        URL=web+number+extension
        
        
    
  # sending get request 

        try:
            r = requests.get(url = URL)
            r.raise_for_status()
            
            
    
   # extracting data in json format and cleaning/transforming the the data 

        
        
            title = r.json()['title']
            alt_text = r.json()['alt']
            num = r.json()['num']
            link = r.json()['link']
            image_link = r.json()['img']
            image=r.json()['img'].rsplit('/', 1)[1]
            
            #print(title,alt_text,num,link,image_link,image)
            
    
            dict_format = {'comic' : title,
                       'comic_meta' : {
                            'alt_text' : alt_text,
                            'number' : num,
                            'link' : link,
                            'image' : image,
                            'image_link' : image_link}}
            
            list.append(dict_format)
    

            
            
        except requests.exceptions.HTTPError as errh:
            print(errh)
        except requests.exceptions.ConnectionError as errc:
            print(errc)
            
    json_object = json.dumps(list, indent = 4)
    print(json_object)


        
def main():
    comic_details()
    
if __name__=='__main__':
    main()
# Out:
# [
#     {
#         "comic": "Godel, Escher, Kurt Halsey",
#         "comic_meta": {
#             "alt_text": "I love the idea here, though of course it's not a great-quality drawing or scan.",
#             "number": 24,
#             "link": "",
#             "image": "godel_escher_kurthalsey.jpg",
#             "image_link": "https://imgs.xkcd.com/comics/godel_escher_kurthalsey.jpg"
#         }
#     },
#     {
#         "comic": "Graduation",
#         "comic_meta": {
#             "alt_text": "Opening dialogue by Scott",
#             "number": 59,
#             "link": "",
#             "image": "graduation.jpg",
#             "image_link": "https://imgs.xkcd.com/comics/graduation.jpg"
#         }
#     },
#     {
#         "comic": "Scientists",
#         "comic_meta": {
#             "alt_text": "A leading expert characterized the situation as 'retarded'",
#             "number": 36,
#             "link": "",
#             "image": "scientists.jpg",
#             "image_link": "https://imgs.xkcd.com/comics/scientists.jpg"
#         }
#     },
#     {
#         "comic": "Poisson",
#         "comic_meta": {
#             "alt_text": "Poisson distributions have no value over negative numbers",
#             "number": 12,
#             "link": "",
#             "image": "poisson.jpg",
#             "image_link": "https://imgs.xkcd.com/comics/poisson.jpg"
#         }
#     },
#     {
#         "comic": "Red spiders",
#         "comic_meta": {
#             "alt_text": "They are six-legged spiders",
#             "number": 8,
#             "link": "",
#             "image": "red_spiders_small.jpg",
#             "image_link": "https://imgs.xkcd.com/comics/red_spiders_small.jpg"
#         }
#     },
#     {
#         "comic": "Classhole",
#         "comic_meta": {
#             "alt_text": "A term coined by my friend Beth",
#             "number": 72,
#             "link": "",
#             "image": "classhole.jpg",
#             "image_link": "https://imgs.xkcd.com/comics/classhole.jpg"
#         }
#     },
#     {
#         "comic": "Hitler",
#         "comic_meta": {
#             "alt_text": "So he's saying that God thought Hitler's art was so bad that the Holocaust was an acceptable alternative.  It's no secret that the hat guy is closely based on Aram, from Men in Hats.",
#             "number": 29,
#             "link": "",
#             "image": "hitler.jpg",
#             "image_link": "https://imgs.xkcd.com/comics/hitler.jpg"
#         }
#     },
#     {
#         "comic": "Fourier",
#         "comic_meta": {
#             "alt_text": "That cat has some serious periodic components",
#             "number": 26,
#             "link": "",
#             "image": "fourier.jpg",
#             "image_link": "https://imgs.xkcd.com/comics/fourier.jpg"
#         }
#     },
#     {
#         "comic": "Attention, shopper",
#         "comic_meta": {
#             "alt_text": "There's a red convertible outside my building with the license plate 'DADS MNY'.",
#             "number": 81,
#             "link": "",
#             "image": "attention_shopper.jpg",
#             "image_link": "https://imgs.xkcd.com/comics/attention_shopper.jpg"
#         }
#     },
#     {
#         "comic": "Island (sketch)",
#         "comic_meta": {
#             "alt_text": "Hello, island",
#             "number": 3,
#             "link": "",
#             "image": "island_color.jpg",
#             "image_link": "https://imgs.xkcd.com/comics/island_color.jpg"
#         }
#     },
#     {
#         "comic": "Ferret",
#         "comic_meta": {
#             "alt_text": "My brother had a ferret he loved which died since I drew this strip.  RIP.",
#             "number": 20,
#             "link": "",
#             "image": "ferret.jpg",
#             "image_link": "https://imgs.xkcd.com/comics/ferret.jpg"
#         }
#     },
#     {
#         "comic": "In the Trees",
#         "comic_meta": {
#             "alt_text": "It was tricky.",
#             "number": 71,
#             "link": "",
#             "image": "in_the_trees.jpg",
#             "image_link": "https://imgs.xkcd.com/comics/in_the_trees.jpg"
#         }
#     },
#     {
#         "comic": "Meat Cereals",
#         "comic_meta": {
#             "alt_text": "Disgusting",
#             "number": 27,
#             "link": "",
#             "image": "meat_cereals.jpg",
#             "image_link": "https://imgs.xkcd.com/comics/meat_cereals.jpg"
#         }
#     },
#     {
#         "comic": "Zeppelin",
#         "comic_meta": {
#             "alt_text": "A tribute to Buttercup Festival",
#             "number": 73,
#             "link": "",
#             "image": "zeppelin.jpg",
#             "image_link": "https://imgs.xkcd.com/comics/zeppelin.jpg"
#         }
#     },
#     {
#         "comic": "Love",
#         "comic_meta": {
#             "alt_text": "This one makes me wince every time I think about it",
#             "number": 44,
#             "link": "",
#             "image": "love.jpg",
#             "image_link": "https://imgs.xkcd.com/comics/love.jpg"
#         }
#     }
# ]
